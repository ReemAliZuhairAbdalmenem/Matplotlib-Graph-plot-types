# %%
import matplotlib.pyplot as plt

# %%
Array_x = [ 2,  5, 6 , 9 , 12 , 15 , 18, 22]
Array_y = [2009,2010,2011,2012,2018,2020,2022,2025]

plt.plot(Array_x , Array_y)
plt.legend('Year Anlysis')
plt.xlabel('Row')
plt.ylabel('column')
plt.title('Data Anlysis year growth')
rray_x = [ 2,  5, 6 , 9 , 12 , 15 , 18, 22]
rray_y = [2009,2010,2011,2012,2018,2020,2022,2025]

plt.plot(rray_x , rray_y)
plt.grid(2)
plt.savefig('Data Anlysis year growth.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
Array_x = [5,10,15,20,25,30,35,40,45,50,55,60]
Array_y = [5,10,15,20,25,30,35,40,45,50,55,60]

plt.bar(Array_x , Array_y ,color ='gray')
plt.grid(2)
plt.title('Data Anlysis Bar chart')
plt.xlabel('Numbers')
plt.ylabel('cold')
plt.legend('Data')
plt.savefig('Data Anlysis Bar chart.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
Array_x = [5,10,15,20,25,30,35,40,45,50,55,60]
Array_y = [5,10,15,20,25,30,35,40,45,50,55,60]

plt.stem(Array_x , Array_y )
plt.grid(2)
plt.title('Data Anlysis Bar chart')
plt.xlabel('Numbers')
plt.ylabel('cold')
plt.legend('Data')
plt.savefig('Data Anlysis Bar chart.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
Array_x = [5,10,15,20,25,30,35,40,45,50,55,60]
Array_y = [5,10,15,20,25,30,35,40,45,50,55,60]

plt.scatter(Array_x , Array_y )
plt.grid(2)
plt.title('Data Anlysis Bar chart')
plt.xlabel('Numbers')
plt.ylabel('cold')
plt.legend('Data')
plt.savefig('Data Anlysis Bar chart.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
Array_x = [5,10,15,20,25,30,35,40,45,50,55,60]
Array_y = [5,10,15,20,25,30,35,40,45,50,55,60]

plt.step(Array_x , Array_y )
plt.grid(2)
plt.title('Data Anlysis Bar chart')
plt.xlabel('Numbers')
plt.ylabel('cold')
plt.legend('Data')
plt.savefig('Data Anlysis Bar chart.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
Array_x = [5,10,15,20,25,30,35,40]
Array_y = [5,10,15,20,45,50,55,60]

plt.fill_between(Array_x , Array_y )
plt.grid(2)
plt.title('Data Anlysis Bar chart')
plt.xlabel('Numbers')
plt.ylabel('cold')
plt.legend('Data')
plt.savefig('Data Anlysis Bar chart.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
Array_x = [5,10,15,20,30,35,40]
Array_y = [5,10,15,45,50,55,60]

plt.stackplot(Array_x , Array_y )
plt.grid(2)
plt.title('Data Anlysis Bar chart')
plt.xlabel('Numbers')
plt.ylabel('cold')
plt.legend('Data')
plt.savefig('Data Anlysis Bar chart.png')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np

# %%
plt.style.use('_mpl-gallery')

# Make data
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_surface(X, Y, Z, vmin=Z.min() * 2, cmap=cm.Blues)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()
